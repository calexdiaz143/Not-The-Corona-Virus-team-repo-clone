# %% [markdown]
# # Challenge 2: Dangerous Situtations

# %%
## Import python packages
import pandas as pd
import numpy as np
import math
from collections import defaultdict

from sklearn.feature_extraction.text import  TfidfVectorizer
from nltk.corpus import stopwords
from nltk import word_tokenize, pos_tag
from gensim import corpora
from gensim import models
from gensim import similarities

# %%
# get a list of english stop words
en_stops = set(stopwords.words('english'))

# %% [markdown]
# ## Setup: initialize some constants

# %%
GENERAL_RULES = ['Wear a mask',
    'Stay 6 feet from others',
    'Avoid crowds',
    'Avoid poorly ventilated spaces',
    'Wash your hands often',
    'Cover coughs and sneezes',
    'Clean and disinfect frequently touched surfaces daily',
    'Monitor your health daily',
    'Get vaccinated']

rule_shortNames = ['wear_mask',
    'social_distance',
    'avoid_crowds',
    'poor_ventilation',
    'wash_hands',
    'cover_coughs',
    'disinfect_surfaces',
    'monitor_health',
    'vaccine']

PROMPTS = ["If you are sick with COVID-19",
           "If you are an older adult",
           "If you have asthma",
           "If you are at home caring for a newborn and are diagnosed with or test positive for COVID-19"]

PROMPT_KEYS = ['sick', 'older_adult', 'asthma', 'covid_with_newborn']

# %% [markdown]
# ## Parse the data
# Parse the CDC guidelines text file into a dataframe with two columns.  One collumn is the title headers (start with ***) and second column are the sentences that fall under that header
# (header index helps id the same header)

# %%
def textToDataFrame(text, delimiter):
    """ 
    Takes in input text, splits by delimiter, returns as pandas dataframe with headings as keys e.g. [index, heade, text]
    """
    textArray = text.split(delimiter)
    df = pd.DataFrame(columns=["headerIndex","header", "text"])
    headerIndex = 0
    for line in textArray:
        if len(line) > 0:
            # print(headerIndex)
            # finds the first line in the section and uses that as the heading
            firstNewlineIndex = line.find("\n")
            header = line[0:firstNewlineIndex]
            # print(header)
            # puts the remaining text into dataframe
            df2 = pd.DataFrame({'headerIndex':headerIndex, 'header': header, 'text':(line[firstNewlineIndex + 1:]).replace("\xa0", " ").split("\n")})
            # combines new dataframe with the return dataframe
            df = df.append(df2, ignore_index=True)
            headerIndex += 1
    return df

filename = './data/CDCGuidelines.txt'

with open(filename, encoding="utf8") as myFile:
    data = myFile.read()

df = textToDataFrame(data, "***")
df.sample(10)
# Out:
#      headerIndex                                             header  \
# 1378          29                        Sick Parents and Caregivers
# 2357          41  Additional COVID-19 Guidance for Caregivers of...
# 553           14                 Improve How Your Mask Protects You
# 3264          52                     Personal and Social Activities
# 5159          77                                   If You Have Pets
# 2855          49         Protect Yourself When Using Transportation
# 3505          54                                       Holiday Tips
# 4808          71  For Parents: Multisystem Inflammatory Syndrome...
# 640           15                                     Types of Masks
# 1739          33                                    Pregnant People
#
#                                                    text
# 1378  Anyone who is incapacitated or otherwise unabl...
# 2357
# 553
# 3264  Prioritize attending outdoor activities over i...
# 5159
# 2855
# 3505  Indoors or outdoors, you are more likely to ge...
# 4808
# 640
# 1739

# %%
headers = df['header'].unique()
#just for nice output in notebook
pd.DataFrame(headers)
# Out:
#                                                     0
# 0          Things to know about the COVID-19 Pandemic
# 1                             Symptoms of Coronavirus
# 2                           COVID-19 Testing Overview
# 3             Test for Current Infection (Viral Test)
# 4                             Test for Past Infection
# ..                                                ...
# 76                               COVID-19 And Animals
# 77                                   If You Have Pets
# 78  What to Do if Your Pet Tests Positive for the ...
# 79  Guidance to Reduce the Risk of SARS-CoV-2 Spre...
# 80  Guidance for Handlers of Service and Therapy A...
#
# [81 rows x 1 columns]

# %% [markdown]
# ## Find best matching titles to the prompts
# Next step is to see if we can automatically sort through all the titles
# and find ones that are closely related to one of our categories
# to do this, we need to do some preprocessing on the titles to:
#  - remove stop words, such as: the, of, to, etc.
#  - remove punctuation (i.e., commas, periods, colons, parens)
#  - lower case everything
#  - remove 's' at end of words to reduce plurals

# %%
def removeStopWords(text):
    returnText = ''
    for w in text.split(' '):
        if w not in en_stops and len(w)>0:
            returnText += ' ' + w
    returnText = returnText.strip()
    # print(returnText)
    return returnText

# remove words that appear only once
frequency = defaultdict(int)
combined = list(df['text']) + list(df['header']) + GENERAL_RULES

for text in combined:
    for token in text.split(' '):
        frequency[token] += 1
        
def removeSingleOccurances(text):
    returnText = ''
    for w in text.split(' '):
        if frequency[token] > 1:
            returnText += ' ' + w
    returnText = returnText.strip()
    # print(returnText)
    return returnText

def removePlurals(text):
    returnText = ''
    for w in text.split(' '):
        if w.endswith('s'):
            w = w[:-1]
        returnText += ' ' + w
    returnText = returnText.strip()
    return returnText
    
def nlpCleanup(df, columnName):
    df[columnName] = df[columnName].str.replace('\d+', '',regex=True) # for digits
    df[columnName] = df[columnName].str.replace(r'(\b\w{1,2}\b)', '',regex=True) # for word length lt 2
    df[columnName] = df[columnName].str.replace('[^\w\s]', '',regex=True) # for punctuation 
    df[columnName] = df[columnName].apply(removeStopWords)
    df[columnName] = df[columnName].apply(removeSingleOccurances)
    df[columnName] = df[columnName].apply(removePlurals)
    df[columnName] = df[columnName].str.lower()
    df[columnName] = df[columnName].str.strip()
    return df

# first make copy of unaltered text, this will be needed later
df['header_orig'] = df['header']
df['text_orig'] = df['text']

df = nlpCleanup(df, columnName='header')
df = nlpCleanup(df, columnName='text')

df.sample(10)
# Out:
#      headerIndex                                        header  \
# 3052          50                               large gathering
# 2293          39        pregnancy breastfeeding caring newborn
# 203            6                               contact tracing
# 5241          78  what your pet test positive viru cause covid
# 4973          74          keep children healthy covid pandemic
# 450           10                    how protect yourself other
# 5042          75                      help children learn home
# 3255          52                     personal social activitie
# 4433          66                         know your travel risk
# 939           20                            protect home covid
#
#                                                    text  \
# 3052  choose event take place outside enough space a...
# 2293
# 203
# 5241  follow similar recommended precaution people c...
# 4973  wash hand soap water second encourage child re...
# 450   don take temperature within minute exercising ...
# 5042                            stay touch child school
# 3255  clean disinfect commonly touched surface share...
# 4433     one share food drink personal item people live
# 939   doe prepare serve assist preparing serving foo...
#
#                                             header_orig  \
# 3052                                   Large Gatherings
# 2293  Pregnancy, Breastfeeding, and Caring for Newborns
# 203                                     Contact Tracing
# 5241  What to Do if Your Pet Tests Positive for the ...
# 4973  Keep Children Healthy during the COVID-19 Pand...
# 450                    How to Protect Yourself & Others
# 5042                        Help Children Learn at Home
# 3255                     Personal and Social Activities
# 4433                              Know Your Travel Risk
# 939                     Protect your Home from COVID-19
#
#                                               text_orig
# 3052  Choose events that take place outside with eno...
# 2293
# 203
# 5241  Follow similar recommended precautions as for ...
# 4973  Wash your hands with soap and water for 20 sec...
# 450   Don’t take your temperature within 30 minutes ...
# 5042             Stay in touch with your child’s school
# 3255  Clean and disinfect commonly touched surfaces ...
# 4433  No one shares food, drinks or personal items w...
# 939   Does not prepare, serve, or assist in preparin...

# %% [markdown]
# #### Similarly process the general rules and prompts

# %%
genRulesDf = pd.DataFrame(GENERAL_RULES, columns=['rule'])

genRulesDf = nlpCleanup(genRulesDf, columnName='rule')

genRulesDf.head()
# Out:
#                             rule
# 0                      wear mask
# 1                stay feet other
# 2                    avoid crowd
# 3  avoid poorly ventilated space
# 4                wash hand often

# %%
promptDf = pd.DataFrame(PROMPTS, columns=['prompt'])
promptDf = nlpCleanup(promptDf, columnName='prompt')

promptDf.head()
# Out:
#                                               prompt
# 0                                         sick covid
# 1                                        older adult
# 2                                             asthma
# 3  home caring newborn diagnosed test positive covid

# %% [markdown]
# ## Now vectorize the headers and prompts using TFIDF
#
# learn the bag of words using the titles, and apply the same vectorizer to prompts

# %%
headers = list(pd.Series(df['header'].unique()))

vectorizer = TfidfVectorizer(
    analyzer = 'word',
    # ngram_range=(2,2),
    lowercase = True,
    strip_accents='unicode',
    stop_words='english'
)

headerVects = vectorizer.fit_transform(headers).toarray()
vectorizer.get_feature_names()
# Out:
# ['activitie',
#  'additional',
#  'adult',
#  'air',
#  'animal',
#  'answer',
#  'associated',
#  'asthma',
#  'attending',
#  'avoid',
#  'beache',
#  'behavioral',
#  'breastfeeding',
#  'care',
#  'caregiver',
#  'caring',
#  'cause',
#  'cdc',
#  'certain',
#  'checklist',
#  'children',
#  'cleaning',
#  'close',
#  'communitie',
#  'community',
#  'condition',
#  'contact',
#  'coronaviru',
#  'covid',
#  'crew',
#  'cruise',
#  'current',
#  'deciding',
#  'dementia',
#  'developmental',
#  'disabilitie',
#  'disease',
#  'disinfecting',
#  'disorder',
#  'distancing',
#  'doctor',
#  'drug',
#  'effect',
#  'errand',
#  'essential',
#  'event',
#  'experiencing',
#  'facilitie',
#  'facility',
#  'food',
#  'gathering',
#  'getting',
#  'glove',
#  'guidance',
#  'guide',
#  'hand',
#  'handler',
#  'healthy',
#  'help',
#  'helping',
#  'hiring',
#  'holiday',
#  'home',
#  'homelessnes',
#  'household',
#  'housing',
#  'improve',
#  'improving',
#  'indoor',
#  'infection',
#  'inflammatory',
#  'international',
#  'isolate',
#  'know',
#  'large',
#  'learn',
#  'likely',
#  'live',
#  'living',
#  'longterm',
#  'mask',
#  'medical',
#  'medicine',
#  'mis',
#  'moderate',
#  'multisystem',
#  'newborn',
#  'newly',
#  'nursing',
#  'older',
#  'outdoor',
#  'overview',
#  'pandemic',
#  'parent',
#  'park',
#  'participate',
#  'past',
#  'people',
#  'personal',
#  'pet',
#  'playing',
#  'pool',
#  'population',
#  'positive',
#  'pregnancy',
#  'pregnant',
#  'protect',
#  'quarantine',
#  'quarter',
#  'question',
#  'recreational',
#  'reduce',
#  'refugee',
#  'reinfection',
#  'repair',
#  'resettled',
#  'returning',
#  'risk',
#  'role',
#  'running',
#  'rural',
#  'sanitizer',
#  'sarscov',
#  'select',
#  'service',
#  'setting',
#  'severe',
#  'shared',
#  'ship',
#  'sick',
#  'small',
#  'social',
#  'sport',
#  'sporting',
#  'spread',
#  'spreading',
#  'stop',
#  'store',
#  'stres',
#  'substance',
#  'symptom',
#  'syndrome',
#  'teen',
#  'test',
#  'testing',
#  'therapy',
#  'thing',
#  'tip',
#  'tracing',
#  'transportation',
#  'travel',
#  'traveler',
#  'type',
#  'use',
#  'using',
#  'variant',
#  'ventilation',
#  'viral',
#  'viru',
#  'visit',
#  'visiting',
#  'voter',
#  'wash',
#  'wear',
#  'wellbeing',
#  'wildlife',
#  'work']

# %%
promptList = list(promptDf['prompt'].values)

promptVects = vectorizer.transform(promptList).toarray()

# %% [markdown]
# ## Now measure similarity
# Using cosine similarities between the tfidf vectors
# Return the best matching header for each prompt

# %%
def cosineSimilarity(vector1, vector2):
    dot_product = sum(p*q for p,q in zip(vector1, vector2))
    magnitude = math.sqrt(sum([val**2 for val in vector1])) * math.sqrt(sum([val**2 for val in vector2]))
    if not magnitude:
        return 0
    return dot_product/magnitude
    

sims = []
for j, h in enumerate(headers):
    d = []
    for i, p in enumerate(promptList):
        a = headerVects[j,:]
        b = promptVects[i,:]
        # print(a)
        # print(b)
        cs = cosineSimilarity(a, b)
        d.append(cs)
        # print(cs)
        # break
    sims.append(d)
        
sims = np.array(sims)

bestMatches = np.argmax(sims, axis=0)

relevantHeaders = []
for m in bestMatches:
    relevantHeaders.append(headers[m])

# %%
# set the category for each row in df that matches the relevant 
# header found above
df['category'] = ''

for i, h in enumerate(relevantHeaders):
    df['category'][df['header'] == h] = PROMPT_KEYS[i]

# %% [markdown]
# ### Next step is to limit to rows that match one of the 4 categories

# %%
df = df[np.logical_not(df['category']=='')]

headerDf = df[['headerIndex', 'header', 'category']]
headerDf = headerDf.drop_duplicates()

# print out those rows
headerDf
# Out:
#      headerIndex                                  header            category
# 1127          25                       what you are sick                sick
# 1533          32                             older adult         older_adult
# 2138          39  pregnancy breastfeeding caring newborn  covid_with_newborn
# 2396          42           people moderate severe asthma              asthma

# %% [markdown]
# ## Find actionable instructions
# Next we want to limit these texts to just ones that start with a verb
# Using the part-of-speech tagging capability of nltk

# %%
def startsWithVerb(s):
    # returns if the first word in the sentence is a verb = this is a 
    # shortcut way to check for actionable instructions
    ret = False
    if len(s)>0:
        s=s.lower()
        tag_pos_string = pos_tag(word_tokenize(s))
        firstWordPartOfSpeech = tag_pos_string[0][1]
        ret = firstWordPartOfSpeech in ('VB', 'VBP')
    
    return ret

df['text_orig'] = df['text_orig'].str.replace('@', '', regex=False)
df['text_orig'] = df['text_orig'].str.replace('*', '', regex=False)

df['actionable'] = df['text_orig'].apply(startsWithVerb)

df.sample(10)
# Out:
#      headerIndex                                  header  \
# 1647          32                             older adult
# 2171          39  pregnancy breastfeeding caring newborn
# 1662          32                             older adult
# 1693          32                             older adult
# 2218          39  pregnancy breastfeeding caring newborn
# 2272          39  pregnancy breastfeeding caring newborn
# 2412          42           people moderate severe asthma
# 2220          39  pregnancy breastfeeding caring newborn
# 1646          32                             older adult
# 1157          25                       what you are sick
#
#                                                    text  \
# 1647                            when delay cancel visit
# 2171  part group recommended receive covid vaccine m...
# 1662  regularly check healthcare worker resident fev...
# 1693      endlife care option example advance directive
# 2218
# 2272
# 2412
# 2220  caregiver living home close contact might expo...
# 1646
# 1157
#
#                                             header_orig  \
# 1647                                       Older Adults
# 2171  Pregnancy, Breastfeeding, and Caring for Newborns
# 1662                                       Older Adults
# 1693                                       Older Adults
# 2218  Pregnancy, Breastfeeding, and Caring for Newborns
# 2272  Pregnancy, Breastfeeding, and Caring for Newborns
# 2412              People with Moderate to Severe Asthma
# 2220  Pregnancy, Breastfeeding, and Caring for Newborns
# 1646                                       Older Adults
# 1157                         What to Do If You Are Sick
#
#                                               text_orig            category  \
# 1647                    When to delay or cancel a visit         older_adult
# 2171  If you are part of a group recommended to rece...  covid_with_newborn
# 1662  Regularly check healthcare workers and residen...         older_adult
# 1693  end-of-life care options (for example, advance...         older_adult
# 2218                                                     covid_with_newborn
# 2272                                                     covid_with_newborn
# 2412                                                                 asthma
# 2220  If the caregiver is living in the same home or...  covid_with_newborn
# 1646                                                            older_adult
# 1157                                                                   sick
#
#       actionable
# 1647       False
# 2171       False
# 1662       False
# 1693       False
# 2218       False
# 2272       False
# 2412       False
# 2220       False
# 1646       False
# 1157       False

# %%
# limit to those that start with verb to give actionable instruction
df = df[df['actionable']==True]
df.sample(10)
# Out:
#      headerIndex                                  header  \
# 1142          25                       what you are sick
# 2168          39  pregnancy breastfeeding caring newborn
# 2298          39  pregnancy breastfeeding caring newborn
# 1141          25                       what you are sick
# 2302          39  pregnancy breastfeeding caring newborn
# 1633          32                             older adult
# 2297          39  pregnancy breastfeeding caring newborn
# 1161          25                       what you are sick
# 1158          25                       what you are sick
# 2283          39  pregnancy breastfeeding caring newborn
#
#                                                    text  \
# 1142  get rest stay hydrated take overthecounter med...
# 2168  get recommended vaccine getting recommended va...
# 2298          check baby jaundice yellow color skin eye
# 1141                                          take care
# 2302                             ensure safe sleep baby
# 1633                  encourage social distancing visit
# 2297                          check baby growth feeding
# 1161                                    monitor symptom
# 1158                      see covid animal question pet
# 2283  ask child care program plan place protect baby...
#
#                                             header_orig  \
# 1142                         What to Do If You Are Sick
# 2168  Pregnancy, Breastfeeding, and Caring for Newborns
# 2298  Pregnancy, Breastfeeding, and Caring for Newborns
# 1141                         What to Do If You Are Sick
# 2302  Pregnancy, Breastfeeding, and Caring for Newborns
# 1633                                       Older Adults
# 2297  Pregnancy, Breastfeeding, and Caring for Newborns
# 1161                         What to Do If You Are Sick
# 1158                         What to Do If You Are Sick
# 2283  Pregnancy, Breastfeeding, and Caring for Newborns
#
#                                               text_orig            category  \
# 1142  Get rest and stay hydrated. Take over-the-coun...                sick
# 2168  Get recommended vaccines. Getting the recommen...  covid_with_newborn
# 2298  Check your baby for jaundice (yellow color in ...  covid_with_newborn
# 1141                            Take care of yourself.                 sick
# 2302                    Ensure safe sleep for your baby  covid_with_newborn
# 1633      Encourage social distancing during your visit         older_adult
# 2297              Check your baby’s growth and feeding.  covid_with_newborn
# 1161                             Monitor your symptoms.                sick
# 1158  See COVID-19 and Animals if you have questions...                sick
# 2283  Ask your child care program about the plans th...  covid_with_newborn
#
#       actionable
# 1142        True
# 2168        True
# 2298        True
# 1141        True
# 2302        True
# 1633        True
# 2297        True
# 1161        True
# 1158        True
# 2283        True

# %%
# this shows the number of instructions by category
# note that we cannot have more than 20 instructions per category
# TODO: we have too many instructions for each category right now...
# this is probably because there are some duplicated instructions within each category
# need to do a self-similarity comparison to remove dups
df.groupby('category').count()
# Out:
#                     headerIndex  header  text  header_orig  text_orig  \
# category
# asthma                        3       3     3            3          3
# covid_with_newborn           38      38    38           38         38
# older_adult                  22      22    22           22         22
# sick                         16      16    16           16         16
#
#                     actionable
# category
# asthma                       3
# covid_with_newborn          38
# older_adult                 22
# sick                        16

# %% [markdown]
# ## Now compare general to specific rules
# Next we want to compare the general rules against the rules that passed all
# previous processing steps and find the union.  Using the LSI model to find phrase
# similarity.  When a phrase is similar enough drop that general rule,
# else add that general rule for that category.
# We'll also use phrase similarity to remove duplicate instructions within each category

# %%
# this creates a dictionary and bag of words encoding based on all text
headers = list(pd.Series(df['header'].unique()).str.split())
texts = list(df['text'].str.split()) 
generalRules = list(genRulesDf['rule'].str.split())
allWords = texts + headers + generalRules
dictionary = corpora.Dictionary(allWords)
# create corpus based on text (not headers)
corpus = [dictionary.doc2bow(text) for text in texts]
# create 2-d lsi model using gensim
lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=2)
index = similarities.MatrixSimilarity(lsi[corpus])

# %% [markdown]
# ## TODO
# Next we need to remove duplicate/highly overlapping instructions within this list
# For example, "Keep track of your symptoms." and "Monitor your symptoms." are
# very similar instructions given for sick people.
# We need to remove the dups within each category.

# %% [markdown]
# ### Add a column to show similarity of each row to the general rules

# %%
for i, gen in enumerate(genRulesDf.values):
    gen = gen[0].split()
    vec_bow = dictionary.doc2bow(gen)
    vec_lsi = lsi[vec_bow]
    sims = index[vec_lsi]
    df[rule_shortNames[i]] = sims

df
# Out:
#      headerIndex                                  header  \
# 1131          25                       what you are sick
# 1141          25                       what you are sick
# 1142          25                       what you are sick
# 1154          25                       what you are sick
# 1158          25                       what you are sick
# ...          ...                                     ...
# 2312          39  pregnancy breastfeeding caring newborn
# 2313          39  pregnancy breastfeeding caring newborn
# 2403          42           people moderate severe asthma
# 2404          42           people moderate severe asthma
# 2407          42           people moderate severe asthma
#
#                                                    text  \
# 1131                                 keep track symptom
# 1141                                          take care
# 1142  get rest stay hydrated take overthecounter med...
# 1154  tell close contact may exposed covid infected ...
# 1158                      see covid animal question pet
# ...                                                 ...
# 2312  cover baby head allow baby get hot sign baby m...
# 2313               smoke allow anyone smoke around baby
# 2403                make sure least day supply medicine
# 2404  take everyday precaution like washing hand avo...
# 2407  wash hand often soap water least second use ha...
#
#                                             header_orig  \
# 1131                         What to Do If You Are Sick
# 1141                         What to Do If You Are Sick
# 1142                         What to Do If You Are Sick
# 1154                         What to Do If You Are Sick
# 1158                         What to Do If You Are Sick
# ...                                                 ...
# 2312  Pregnancy, Breastfeeding, and Caring for Newborns
# 2313  Pregnancy, Breastfeeding, and Caring for Newborns
# 2403              People with Moderate to Severe Asthma
# 2404              People with Moderate to Severe Asthma
# 2407              People with Moderate to Severe Asthma
#
#                                               text_orig            category  \
# 1131                       Keep track of your symptoms.                sick
# 1141                            Take care of yourself.                 sick
# 1142  Get rest and stay hydrated. Take over-the-coun...                sick
# 1154  Tell your close contacts that they may have be...                sick
# 1158  See COVID-19 and Animals if you have questions...                sick
# ...                                                 ...                 ...
# 2312  Do not cover your baby’s head or allow your ba...  covid_with_newborn
# 2313  Do not smoke or allow anyone to smoke around y...  covid_with_newborn
# 2403  Make sure that you have at least a 30-day supp...              asthma
# 2404  Take everyday precautions like washing your ha...              asthma
# 2407  Wash your hands often with soap and water for ...              asthma
#
#       actionable  wear_mask  social_distance  avoid_crowds  poor_ventilation  \
# 1131        True   0.995549         0.953137           0.0               0.0
# 1141        True   0.932023         0.834367           0.0               0.0
# 1142        True   0.973809         0.903749           0.0               0.0
# 1154        True   0.938728         0.844670           0.0               0.0
# 1158        True   0.923836         0.822055           0.0               0.0
# ...          ...        ...              ...           ...               ...
# 2312        True   0.944050         0.853011           0.0               0.0
# 2313        True   0.956205         0.872735           0.0               0.0
# 2403        True   0.544769         0.709711           0.0               0.0
# 2404        True   0.633506         0.782736           0.0               0.0
# 2407        True   0.368526         0.556691           0.0               0.0
#
#       wash_hands  cover_coughs  disinfect_surfaces  monitor_health   vaccine
# 1131    0.274072      0.966456            0.277825        0.958774  0.960937
# 1141    0.001166      0.999860            0.005071        0.999932  0.999992
# 1142    0.142148      0.992229            0.146013        0.988296  0.989443
# 1154    0.020130      0.999997            0.024034        0.999530  0.999737
# 1158   -0.020806      0.999252           -0.016901        0.999947  0.999838
# ...          ...           ...                 ...             ...       ...
# 2312    0.035902      0.999837            0.039805        0.998923  0.999251
# 2313    0.074889      0.998371            0.078783        0.996349  0.996978
# 2403    0.979242      0.220170            0.980026        0.192387  0.199949
# 2404    0.951084      0.325888            0.952283        0.298915  0.306266
# 2407    0.999985      0.023295            0.999999       -0.005097  0.002615
#
# [79 rows x 16 columns]

# %% [markdown]
# ## Find overlapping/very similar phrases
# Using a threshold to find where the general rules are duplicated in the specific rules.  This threshold was derived using some trial and error.

# %%
THRESHOLD = 0.999995

dfs = []

for cat in PROMPT_KEYS:
    print('--------')
    print(cat)
    tempDf = df[df['category'] == cat]
    text = tempDf['text']
    
    for i, rule in enumerate(rule_shortNames):
        dupRule = np.any(tempDf[rule] > THRESHOLD)

        if not dupRule:
            newRule = pd.DataFrame([[cat, GENERAL_RULES[i]]], columns=['category', 'text_orig'])
            tempDf = pd.concat([tempDf,newRule])
            print('    ***')
            print('    No dup found:', rule)
            print('       ', list(tempDf['text'].values))
        else:
            print('    ***')
            print('    found dup:', rule)
            print('       ', list(tempDf['text'][tempDf[rule] > THRESHOLD].values))
            
    dfs.append(tempDf[['category','text_orig']])

finalDf = pd.concat(dfs)
# Out:
# --------
# sick
#     ***
#     No dup found: wear_mask
#         ['keep track symptom', 'take care', 'get rest stay hydrated take overthecounter medicine acetaminophen help feel better', 'tell close contact may exposed covid infected person spread covid starting hour day person symptom test positive letting close contact know may exposed covid helping protect everyone', 'see covid animal question pet', 'monitor symptom', 'follow care instruction healthcare provider local health department your local health authoritie may give instruction checking symptom reporting information', 'call call ahead local emergency facility notify operator seeking care someone may covid', 'cover cough sneeze', 'cover mouth nose tissue cough sneeze', 'throw away used tissue lined trash', 'clean hand often', 'wash hand', 'share dishe drinking glasse cup eating utensil towel bedding people home', 'clean area item soap water another detergent dirty then use household disinfectant', 'sure follow instruction label ensure safe effective use product', nan]
#     ***
#     No dup found: social_distance
#         ['keep track symptom', 'take care', 'get rest stay hydrated take overthecounter medicine acetaminophen help feel better', 'tell close contact may exposed covid infected person spread covid starting hour day person symptom test positive letting close contact know may exposed covid helping protect everyone', 'see covid animal question pet', 'monitor symptom', 'follow care instruction healthcare provider local health department your local health authoritie may give instruction checking symptom reporting information', 'call call ahead local emergency facility notify operator seeking care someone may covid', 'cover cough sneeze', 'cover mouth nose tissue cough sneeze', 'throw away used tissue lined trash', 'clean hand often', 'wash hand', 'share dishe drinking glasse cup eating utensil towel bedding people home', 'clean area item soap water another detergent dirty then use household disinfectant', 'sure follow instruction label ensure safe effective use product', nan, nan]
#     ***
#     No dup found: avoid_crowds
#         ['keep track symptom', 'take care', 'get rest stay hydrated take overthecounter medicine acetaminophen help feel better', 'tell close contact may exposed covid infected person spread covid starting hour day person symptom test positive letting close contact know may exposed covid helping protect everyone', 'see covid animal question pet', 'monitor symptom', 'follow care instruction healthcare provider local health department your local health authoritie may give instruction checking symptom reporting information', 'call call ahead local emergency facility notify operator seeking care someone may covid', 'cover cough sneeze', 'cover mouth nose tissue cough sneeze', 'throw away used tissue lined trash', 'clean hand often', 'wash hand', 'share dishe drinking glasse cup eating utensil towel bedding people home', 'clean area item soap water another detergent dirty then use household disinfectant', 'sure follow instruction label ensure safe effective use product', nan, nan, nan]
#     ***
#     No dup found: poor_ventilation
#         ['keep track symptom', 'take care', 'get rest stay hydrated take overthecounter medicine acetaminophen help feel better', 'tell close contact may exposed covid infected person spread covid starting hour day person symptom test positive letting close contact know may exposed covid helping protect everyone', 'see covid animal question pet', 'monitor symptom', 'follow care instruction healthcare provider local health department your local health authoritie may give instruction checking symptom reporting information', 'call call ahead local emergency facility notify operator seeking care someone may covid', 'cover cough sneeze', 'cover mouth nose tissue cough sneeze', 'throw away used tissue lined trash', 'clean hand often', 'wash hand', 'share dishe drinking glasse cup eating utensil towel bedding people home', 'clean area item soap water another detergent dirty then use household disinfectant', 'sure follow instruction label ensure safe effective use product', nan, nan, nan, nan]
#     ***
#     found dup: wash_hands
#         ['clean hand often', 'wash hand']
#     ***
#     found dup: cover_coughs
#         ['tell close contact may exposed covid infected person spread covid starting hour day person symptom test positive letting close contact know may exposed covid helping protect everyone', 'cover cough sneeze']
#     ***
#     found dup: disinfect_surfaces
#         ['clean hand often']
#     ***
#     found dup: monitor_health
#         ['follow care instruction healthcare provider local health department your local health authoritie may give instruction checking symptom reporting information']
#     ***
#     found dup: vaccine
#         ['monitor symptom']
# --------
# older_adult
#     ***
#     No dup found: wear_mask
#         ['change treatment plan without talking healthcare provider', 'have least day supply medicine', 'delay getting emergency care', 'call healthcare provider underlying medical condition', 'reduce your risk getting sick', 'keep feet distance', 'don touch face', 'consider level risk deciding ensure people increased risk severe illnes covid live taking step protect', 'consider level risk', 'consider avoiding activitie taking protective measure may difficult activitie social distancing maintained', 'take step protect yourself', 'keep item hand use venturing mask tissue hand sanitizer least alcohol', 'encourage social distancing visit', 'consider keeping list people visited visited visit occurred thi help contact tracing someone become sick', 'consider current level covid infection specific community infection widespread consider delaying cancelling visit', 'contact your healthcare provider seek care', 'check your symptom', 'aware single reading higher multiple reading rise temperature greater patient normal baseline temperature may sign infection', 'develop care plan', 'complete care plan consultation doctor needed help family member caregiver home health aide', 'remember importance staying physically active practicing healthy habit cope stres', 'get tip staying connected home english spanish icon there community agencie may able help call line provide friendly voice emotional support older adult', nan]
#     ***
#     No dup found: social_distance
#         ['change treatment plan without talking healthcare provider', 'have least day supply medicine', 'delay getting emergency care', 'call healthcare provider underlying medical condition', 'reduce your risk getting sick', 'keep feet distance', 'don touch face', 'consider level risk deciding ensure people increased risk severe illnes covid live taking step protect', 'consider level risk', 'consider avoiding activitie taking protective measure may difficult activitie social distancing maintained', 'take step protect yourself', 'keep item hand use venturing mask tissue hand sanitizer least alcohol', 'encourage social distancing visit', 'consider keeping list people visited visited visit occurred thi help contact tracing someone become sick', 'consider current level covid infection specific community infection widespread consider delaying cancelling visit', 'contact your healthcare provider seek care', 'check your symptom', 'aware single reading higher multiple reading rise temperature greater patient normal baseline temperature may sign infection', 'develop care plan', 'complete care plan consultation doctor needed help family member caregiver home health aide', 'remember importance staying physically active practicing healthy habit cope stres', 'get tip staying connected home english spanish icon there community agencie may able help call line provide friendly voice emotional support older adult', nan, nan]
#     ***
#     No dup found: avoid_crowds
#         ['change treatment plan without talking healthcare provider', 'have least day supply medicine', 'delay getting emergency care', 'call healthcare provider underlying medical condition', 'reduce your risk getting sick', 'keep feet distance', 'don touch face', 'consider level risk deciding ensure people increased risk severe illnes covid live taking step protect', 'consider level risk', 'consider avoiding activitie taking protective measure may difficult activitie social distancing maintained', 'take step protect yourself', 'keep item hand use venturing mask tissue hand sanitizer least alcohol', 'encourage social distancing visit', 'consider keeping list people visited visited visit occurred thi help contact tracing someone become sick', 'consider current level covid infection specific community infection widespread consider delaying cancelling visit', 'contact your healthcare provider seek care', 'check your symptom', 'aware single reading higher multiple reading rise temperature greater patient normal baseline temperature may sign infection', 'develop care plan', 'complete care plan consultation doctor needed help family member caregiver home health aide', 'remember importance staying physically active practicing healthy habit cope stres', 'get tip staying connected home english spanish icon there community agencie may able help call line provide friendly voice emotional support older adult', nan, nan, nan]
#     ***
#     No dup found: poor_ventilation
#         ['change treatment plan without talking healthcare provider', 'have least day supply medicine', 'delay getting emergency care', 'call healthcare provider underlying medical condition', 'reduce your risk getting sick', 'keep feet distance', 'don touch face', 'consider level risk deciding ensure people increased risk severe illnes covid live taking step protect', 'consider level risk', 'consider avoiding activitie taking protective measure may difficult activitie social distancing maintained', 'take step protect yourself', 'keep item hand use venturing mask tissue hand sanitizer least alcohol', 'encourage social distancing visit', 'consider keeping list people visited visited visit occurred thi help contact tracing someone become sick', 'consider current level covid infection specific community infection widespread consider delaying cancelling visit', 'contact your healthcare provider seek care', 'check your symptom', 'aware single reading higher multiple reading rise temperature greater patient normal baseline temperature may sign infection', 'develop care plan', 'complete care plan consultation doctor needed help family member caregiver home health aide', 'remember importance staying physically active practicing healthy habit cope stres', 'get tip staying connected home english spanish icon there community agencie may able help call line provide friendly voice emotional support older adult', nan, nan, nan, nan]
#     ***
#     No dup found: wash_hands
#         ['change treatment plan without talking healthcare provider', 'have least day supply medicine', 'delay getting emergency care', 'call healthcare provider underlying medical condition', 'reduce your risk getting sick', 'keep feet distance', 'don touch face', 'consider level risk deciding ensure people increased risk severe illnes covid live taking step protect', 'consider level risk', 'consider avoiding activitie taking protective measure may difficult activitie social distancing maintained', 'take step protect yourself', 'keep item hand use venturing mask tissue hand sanitizer least alcohol', 'encourage social distancing visit', 'consider keeping list people visited visited visit occurred thi help contact tracing someone become sick', 'consider current level covid infection specific community infection widespread consider delaying cancelling visit', 'contact your healthcare provider seek care', 'check your symptom', 'aware single reading higher multiple reading rise temperature greater patient normal baseline temperature may sign infection', 'develop care plan', 'complete care plan consultation doctor needed help family member caregiver home health aide', 'remember importance staying physically active practicing healthy habit cope stres', 'get tip staying connected home english spanish icon there community agencie may able help call line provide friendly voice emotional support older adult', nan, nan, nan, nan, nan]
#     ***
#     found dup: cover_coughs
#         ['consider level risk deciding ensure people increased risk severe illnes covid live taking step protect', 'contact your healthcare provider seek care']
#     ***
#     No dup found: disinfect_surfaces
#         ['change treatment plan without talking healthcare provider', 'have least day supply medicine', 'delay getting emergency care', 'call healthcare provider underlying medical condition', 'reduce your risk getting sick', 'keep feet distance', 'don touch face', 'consider level risk deciding ensure people increased risk severe illnes covid live taking step protect', 'consider level risk', 'consider avoiding activitie taking protective measure may difficult activitie social distancing maintained', 'take step protect yourself', 'keep item hand use venturing mask tissue hand sanitizer least alcohol', 'encourage social distancing visit', 'consider keeping list people visited visited visit occurred thi help contact tracing someone become sick', 'consider current level covid infection specific community infection widespread consider delaying cancelling visit', 'contact your healthcare provider seek care', 'check your symptom', 'aware single reading higher multiple reading rise temperature greater patient normal baseline temperature may sign infection', 'develop care plan', 'complete care plan consultation doctor needed help family member caregiver home health aide', 'remember importance staying physically active practicing healthy habit cope stres', 'get tip staying connected home english spanish icon there community agencie may able help call line provide friendly voice emotional support older adult', nan, nan, nan, nan, nan, nan]
#     ***
#     found dup: monitor_health
#         ['call healthcare provider underlying medical condition']
#     ***
#     No dup found: vaccine
#         ['change treatment plan without talking healthcare provider', 'have least day supply medicine', 'delay getting emergency care', 'call healthcare provider underlying medical condition', 'reduce your risk getting sick', 'keep feet distance', 'don touch face', 'consider level risk deciding ensure people increased risk severe illnes covid live taking step protect', 'consider level risk', 'consider avoiding activitie taking protective measure may difficult activitie social distancing maintained', 'take step protect yourself', 'keep item hand use venturing mask tissue hand sanitizer least alcohol', 'encourage social distancing visit', 'consider keeping list people visited visited visit occurred thi help contact tracing someone become sick', 'consider current level covid infection specific community infection widespread consider delaying cancelling visit', 'contact your healthcare provider seek care', 'check your symptom', 'aware single reading higher multiple reading rise temperature greater patient normal baseline temperature may sign infection', 'develop care plan', 'complete care plan consultation doctor needed help family member caregiver home health aide', 'remember importance staying physically active practicing healthy habit cope stres', 'get tip staying connected home english spanish icon there community agencie may able help call line provide friendly voice emotional support older adult', nan, nan, nan, nan, nan, nan, nan]
# --------
# asthma
#     ***
#     No dup found: wear_mask
#         ['make sure least day supply medicine', 'take everyday precaution like washing hand avoiding close contact staying least feet arm length people', 'wash hand often soap water least second use hand sanitizer contain least alcohol', nan]
#     ***
#     No dup found: social_distance
#         ['make sure least day supply medicine', 'take everyday precaution like washing hand avoiding close contact staying least feet arm length people', 'wash hand often soap water least second use hand sanitizer contain least alcohol', nan, nan]
#     ***
#     No dup found: avoid_crowds
#         ['make sure least day supply medicine', 'take everyday precaution like washing hand avoiding close contact staying least feet arm length people', 'wash hand often soap water least second use hand sanitizer contain least alcohol', nan, nan, nan]
#     ***
#     No dup found: poor_ventilation
#         ['make sure least day supply medicine', 'take everyday precaution like washing hand avoiding close contact staying least feet arm length people', 'wash hand often soap water least second use hand sanitizer contain least alcohol', nan, nan, nan, nan]
#     ***
#     No dup found: wash_hands
#         ['make sure least day supply medicine', 'take everyday precaution like washing hand avoiding close contact staying least feet arm length people', 'wash hand often soap water least second use hand sanitizer contain least alcohol', nan, nan, nan, nan, nan]
#     ***
#     No dup found: cover_coughs
#         ['make sure least day supply medicine', 'take everyday precaution like washing hand avoiding close contact staying least feet arm length people', 'wash hand often soap water least second use hand sanitizer contain least alcohol', nan, nan, nan, nan, nan, nan]
#     ***
#     found dup: disinfect_surfaces
#         ['wash hand often soap water least second use hand sanitizer contain least alcohol']
#     ***
#     No dup found: monitor_health
#         ['make sure least day supply medicine', 'take everyday precaution like washing hand avoiding close contact staying least feet arm length people', 'wash hand often soap water least second use hand sanitizer contain least alcohol', nan, nan, nan, nan, nan, nan, nan]
#     ***
#     No dup found: vaccine
#         ['make sure least day supply medicine', 'take everyday precaution like washing hand avoiding close contact staying least feet arm length people', 'wash hand often soap water least second use hand sanitizer contain least alcohol', nan, nan, nan, nan, nan, nan, nan, nan]
# --------
# covid_with_newborn
#     ***
#     No dup found: wear_mask
#         ['take step prevent getting covid interact other', 'wash hand soap water least second soap water available use hand sanitizer least alcohol', 'keep healthcare appointment pregnancy visit healthcare provider recommended appointment concerned going appointment covid ask healthcare provider step taking separate healthy patient might sick need help finding healthcare provider contact nearest hospital clinic community health center health department', 'get recommended vaccine getting recommended vaccine pregnancy help protect baby', 'get vaccinated influenza flu other living household also get vaccinated protect', 'get whooping cough tdap vaccine pregnancy protect baby whooping cough similar symptom covid', 'keep least day supply prescription nonprescription medicine talk healthcare provider insurer pharmacist getting extra supply example day prescription medicine possible reduce trip pharmacy', 'call healthcare provider concern pregnancy get sick think may covid', 'delay getting emergency care covid emergency department step place protect getting covid need care need emergency help call right away tell pregnant emergency someone else driving emergency department call way need drive call start driving', 'decide newborn rooming hospital', 'take precaution newborn rooming hospital', 'wash hand soap water least second holding caring newborn soap water available use hand sanitizer least alcohol', 'keep newborn feet away much possible', 'have healthy caregiver increased risk severe illnes provide care newborn', 'wash hand soap water least second touching newborn soap water available use hand sanitizer least alcohol', 'wash hand breastfeeding', 'use breast pump one shared anyone else possible', 'wash hand soap water least second touching pump bottle part expressing breast milk', 'consider healthy caregiver covid increased risk severe illnes covid living home feed expressed breast milk baby caregiver living home close contact might exposed any caregiver feeding baby wear mask caring baby entire time isolation quarantine period complete isolation', 'put face shield mask baby', 'keep distance baby people live household sick', 'consider risk spreading covid baby decide whether activitie healthcare visit child care', 'keep feet distance baby people live household', 'ask child care program plan place protect baby family staff covid', 'know possible sign symptom covid infection among babie', 'bring baby newborn visit', 'check baby overall', 'check baby growth feeding', 'check baby jaundice yellow color skin eye', 'make sure baby newborn screening test done including bloodspot hearing test test critical congenital heart defect repeat follow testing necessary', 'ensure safe sleep baby', 'take step reduce risk sudden infant death syndrome sids sleeprelated death following', 'place baby back sleep time nap night', 'use firm flat sleep surface mattres crib covered fitted sheet', 'have baby share room bed your baby sleep adult bed cot air mattres couch chair whether sleeping alone anyone else', 'keep soft bedding blanket pillow bumper pad soft toy baby sleep area', 'cover baby head allow baby get hot sign baby may getting hot include sweating chest feeling hot', 'smoke allow anyone smoke around baby', nan]
#     ***
#     No dup found: social_distance
#         ['take step prevent getting covid interact other', 'wash hand soap water least second soap water available use hand sanitizer least alcohol', 'keep healthcare appointment pregnancy visit healthcare provider recommended appointment concerned going appointment covid ask healthcare provider step taking separate healthy patient might sick need help finding healthcare provider contact nearest hospital clinic community health center health department', 'get recommended vaccine getting recommended vaccine pregnancy help protect baby', 'get vaccinated influenza flu other living household also get vaccinated protect', 'get whooping cough tdap vaccine pregnancy protect baby whooping cough similar symptom covid', 'keep least day supply prescription nonprescription medicine talk healthcare provider insurer pharmacist getting extra supply example day prescription medicine possible reduce trip pharmacy', 'call healthcare provider concern pregnancy get sick think may covid', 'delay getting emergency care covid emergency department step place protect getting covid need care need emergency help call right away tell pregnant emergency someone else driving emergency department call way need drive call start driving', 'decide newborn rooming hospital', 'take precaution newborn rooming hospital', 'wash hand soap water least second holding caring newborn soap water available use hand sanitizer least alcohol', 'keep newborn feet away much possible', 'have healthy caregiver increased risk severe illnes provide care newborn', 'wash hand soap water least second touching newborn soap water available use hand sanitizer least alcohol', 'wash hand breastfeeding', 'use breast pump one shared anyone else possible', 'wash hand soap water least second touching pump bottle part expressing breast milk', 'consider healthy caregiver covid increased risk severe illnes covid living home feed expressed breast milk baby caregiver living home close contact might exposed any caregiver feeding baby wear mask caring baby entire time isolation quarantine period complete isolation', 'put face shield mask baby', 'keep distance baby people live household sick', 'consider risk spreading covid baby decide whether activitie healthcare visit child care', 'keep feet distance baby people live household', 'ask child care program plan place protect baby family staff covid', 'know possible sign symptom covid infection among babie', 'bring baby newborn visit', 'check baby overall', 'check baby growth feeding', 'check baby jaundice yellow color skin eye', 'make sure baby newborn screening test done including bloodspot hearing test test critical congenital heart defect repeat follow testing necessary', 'ensure safe sleep baby', 'take step reduce risk sudden infant death syndrome sids sleeprelated death following', 'place baby back sleep time nap night', 'use firm flat sleep surface mattres crib covered fitted sheet', 'have baby share room bed your baby sleep adult bed cot air mattres couch chair whether sleeping alone anyone else', 'keep soft bedding blanket pillow bumper pad soft toy baby sleep area', 'cover baby head allow baby get hot sign baby may getting hot include sweating chest feeling hot', 'smoke allow anyone smoke around baby', nan, nan]
#     ***
#     No dup found: avoid_crowds
#         ['take step prevent getting covid interact other', 'wash hand soap water least second soap water available use hand sanitizer least alcohol', 'keep healthcare appointment pregnancy visit healthcare provider recommended appointment concerned going appointment covid ask healthcare provider step taking separate healthy patient might sick need help finding healthcare provider contact nearest hospital clinic community health center health department', 'get recommended vaccine getting recommended vaccine pregnancy help protect baby', 'get vaccinated influenza flu other living household also get vaccinated protect', 'get whooping cough tdap vaccine pregnancy protect baby whooping cough similar symptom covid', 'keep least day supply prescription nonprescription medicine talk healthcare provider insurer pharmacist getting extra supply example day prescription medicine possible reduce trip pharmacy', 'call healthcare provider concern pregnancy get sick think may covid', 'delay getting emergency care covid emergency department step place protect getting covid need care need emergency help call right away tell pregnant emergency someone else driving emergency department call way need drive call start driving', 'decide newborn rooming hospital', 'take precaution newborn rooming hospital', 'wash hand soap water least second holding caring newborn soap water available use hand sanitizer least alcohol', 'keep newborn feet away much possible', 'have healthy caregiver increased risk severe illnes provide care newborn', 'wash hand soap water least second touching newborn soap water available use hand sanitizer least alcohol', 'wash hand breastfeeding', 'use breast pump one shared anyone else possible', 'wash hand soap water least second touching pump bottle part expressing breast milk', 'consider healthy caregiver covid increased risk severe illnes covid living home feed expressed breast milk baby caregiver living home close contact might exposed any caregiver feeding baby wear mask caring baby entire time isolation quarantine period complete isolation', 'put face shield mask baby', 'keep distance baby people live household sick', 'consider risk spreading covid baby decide whether activitie healthcare visit child care', 'keep feet distance baby people live household', 'ask child care program plan place protect baby family staff covid', 'know possible sign symptom covid infection among babie', 'bring baby newborn visit', 'check baby overall', 'check baby growth feeding', 'check baby jaundice yellow color skin eye', 'make sure baby newborn screening test done including bloodspot hearing test test critical congenital heart defect repeat follow testing necessary', 'ensure safe sleep baby', 'take step reduce risk sudden infant death syndrome sids sleeprelated death following', 'place baby back sleep time nap night', 'use firm flat sleep surface mattres crib covered fitted sheet', 'have baby share room bed your baby sleep adult bed cot air mattres couch chair whether sleeping alone anyone else', 'keep soft bedding blanket pillow bumper pad soft toy baby sleep area', 'cover baby head allow baby get hot sign baby may getting hot include sweating chest feeling hot', 'smoke allow anyone smoke around baby', nan, nan, nan]
#     ***
#     No dup found: poor_ventilation
#         ['take step prevent getting covid interact other', 'wash hand soap water least second soap water available use hand sanitizer least alcohol', 'keep healthcare appointment pregnancy visit healthcare provider recommended appointment concerned going appointment covid ask healthcare provider step taking separate healthy patient might sick need help finding healthcare provider contact nearest hospital clinic community health center health department', 'get recommended vaccine getting recommended vaccine pregnancy help protect baby', 'get vaccinated influenza flu other living household also get vaccinated protect', 'get whooping cough tdap vaccine pregnancy protect baby whooping cough similar symptom covid', 'keep least day supply prescription nonprescription medicine talk healthcare provider insurer pharmacist getting extra supply example day prescription medicine possible reduce trip pharmacy', 'call healthcare provider concern pregnancy get sick think may covid', 'delay getting emergency care covid emergency department step place protect getting covid need care need emergency help call right away tell pregnant emergency someone else driving emergency department call way need drive call start driving', 'decide newborn rooming hospital', 'take precaution newborn rooming hospital', 'wash hand soap water least second holding caring newborn soap water available use hand sanitizer least alcohol', 'keep newborn feet away much possible', 'have healthy caregiver increased risk severe illnes provide care newborn', 'wash hand soap water least second touching newborn soap water available use hand sanitizer least alcohol', 'wash hand breastfeeding', 'use breast pump one shared anyone else possible', 'wash hand soap water least second touching pump bottle part expressing breast milk', 'consider healthy caregiver covid increased risk severe illnes covid living home feed expressed breast milk baby caregiver living home close contact might exposed any caregiver feeding baby wear mask caring baby entire time isolation quarantine period complete isolation', 'put face shield mask baby', 'keep distance baby people live household sick', 'consider risk spreading covid baby decide whether activitie healthcare visit child care', 'keep feet distance baby people live household', 'ask child care program plan place protect baby family staff covid', 'know possible sign symptom covid infection among babie', 'bring baby newborn visit', 'check baby overall', 'check baby growth feeding', 'check baby jaundice yellow color skin eye', 'make sure baby newborn screening test done including bloodspot hearing test test critical congenital heart defect repeat follow testing necessary', 'ensure safe sleep baby', 'take step reduce risk sudden infant death syndrome sids sleeprelated death following', 'place baby back sleep time nap night', 'use firm flat sleep surface mattres crib covered fitted sheet', 'have baby share room bed your baby sleep adult bed cot air mattres couch chair whether sleeping alone anyone else', 'keep soft bedding blanket pillow bumper pad soft toy baby sleep area', 'cover baby head allow baby get hot sign baby may getting hot include sweating chest feeling hot', 'smoke allow anyone smoke around baby', nan, nan, nan, nan]
#     ***
#     found dup: wash_hands
#         ['wash hand breastfeeding']
#     ***
#     No dup found: cover_coughs
#         ['take step prevent getting covid interact other', 'wash hand soap water least second soap water available use hand sanitizer least alcohol', 'keep healthcare appointment pregnancy visit healthcare provider recommended appointment concerned going appointment covid ask healthcare provider step taking separate healthy patient might sick need help finding healthcare provider contact nearest hospital clinic community health center health department', 'get recommended vaccine getting recommended vaccine pregnancy help protect baby', 'get vaccinated influenza flu other living household also get vaccinated protect', 'get whooping cough tdap vaccine pregnancy protect baby whooping cough similar symptom covid', 'keep least day supply prescription nonprescription medicine talk healthcare provider insurer pharmacist getting extra supply example day prescription medicine possible reduce trip pharmacy', 'call healthcare provider concern pregnancy get sick think may covid', 'delay getting emergency care covid emergency department step place protect getting covid need care need emergency help call right away tell pregnant emergency someone else driving emergency department call way need drive call start driving', 'decide newborn rooming hospital', 'take precaution newborn rooming hospital', 'wash hand soap water least second holding caring newborn soap water available use hand sanitizer least alcohol', 'keep newborn feet away much possible', 'have healthy caregiver increased risk severe illnes provide care newborn', 'wash hand soap water least second touching newborn soap water available use hand sanitizer least alcohol', 'wash hand breastfeeding', 'use breast pump one shared anyone else possible', 'wash hand soap water least second touching pump bottle part expressing breast milk', 'consider healthy caregiver covid increased risk severe illnes covid living home feed expressed breast milk baby caregiver living home close contact might exposed any caregiver feeding baby wear mask caring baby entire time isolation quarantine period complete isolation', 'put face shield mask baby', 'keep distance baby people live household sick', 'consider risk spreading covid baby decide whether activitie healthcare visit child care', 'keep feet distance baby people live household', 'ask child care program plan place protect baby family staff covid', 'know possible sign symptom covid infection among babie', 'bring baby newborn visit', 'check baby overall', 'check baby growth feeding', 'check baby jaundice yellow color skin eye', 'make sure baby newborn screening test done including bloodspot hearing test test critical congenital heart defect repeat follow testing necessary', 'ensure safe sleep baby', 'take step reduce risk sudden infant death syndrome sids sleeprelated death following', 'place baby back sleep time nap night', 'use firm flat sleep surface mattres crib covered fitted sheet', 'have baby share room bed your baby sleep adult bed cot air mattres couch chair whether sleeping alone anyone else', 'keep soft bedding blanket pillow bumper pad soft toy baby sleep area', 'cover baby head allow baby get hot sign baby may getting hot include sweating chest feeling hot', 'smoke allow anyone smoke around baby', nan, nan, nan, nan, nan]
#     ***
#     found dup: disinfect_surfaces
#         ['wash hand soap water least second soap water available use hand sanitizer least alcohol', 'wash hand soap water least second touching newborn soap water available use hand sanitizer least alcohol']
#     ***
#     found dup: monitor_health
#         ['call healthcare provider concern pregnancy get sick think may covid']
#     ***
#     found dup: vaccine
#         ['get recommended vaccine getting recommended vaccine pregnancy help protect baby', 'get whooping cough tdap vaccine pregnancy protect baby whooping cough similar symptom covid']

# %% [markdown]
# ### format final output per HTM spec and save to csv

# %%
finalDf.columns = ['situation', 'rules']

finalDf
# Out:
#                situation                                              rules
# 1131                sick                       Keep track of your symptoms.
# 1141                sick                            Take care of yourself.
# 1142                sick  Get rest and stay hydrated. Take over-the-coun...
# 1154                sick  Tell your close contacts that they may have be...
# 1158                sick  See COVID-19 and Animals if you have questions...
# ...                  ...                                                ...
# 0     covid_with_newborn                                        Wear a mask
# 0     covid_with_newborn                            Stay 6 feet from others
# 0     covid_with_newborn                                       Avoid crowds
# 0     covid_with_newborn                     Avoid poorly ventilated spaces
# 0     covid_with_newborn                           Cover coughs and sneezes
#
# [103 rows x 2 columns]

# %%
fileName = './submission/Challenge2_submission.csv'

finalDf.to_csv(fileName, index=False)

# %% [markdown]
# ## Show final number of rules per situation

# %%
"""
check counts by category
"""
print(finalDf.groupby('situation').count())
# Out:
#                     rules
# situation
# asthma                 11
# covid_with_newborn     43
# older_adult            29
# sick                   20
